# %%
import numpy as np
import os
import cv2 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import glob
import shutil
from PIL import Image

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, MaxPooling2D, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras import models, layers
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, decode_predictions #preprocess_input, 
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input #decode_predictions,
from tensorflow.keras.applications import mobilenet_v2

from tensorflow.keras import preprocessing
from tensorflow.keras.preprocessing import image # Keras own inbuild image class

# %% [markdown]
# # import the data

# %%
df=pd.read_excel('data.xlsx', index_col = 0)

# %%
#df = pd.read_csv('full_df.csv', index_col=0)
df.columns = df.columns.str.replace(' ','_').str.lower()
df.shape
# Out:
# (3500, 14)

# %%
df.head()
# Out:
#     patient_age patient_sex left-fundus right-fundus  \
# ID
# 0            69      Female  0_left.jpg  0_right.jpg
# 1            57        Male  1_left.jpg  1_right.jpg
# 2            42        Male  2_left.jpg  2_right.jpg
# 3            66        Male  3_left.jpg  3_right.jpg
# 4            53        Male  4_left.jpg  4_right.jpg
#
#                              left-diagnostic_keywords  \
# ID
# 0                                            cataract
# 1                                       normal fundus
# 2   laser spot，moderate non proliferative retinopathy
# 3                                       normal fundus
# 4                         macular epiretinal membrane
#
#                  right-diagnostic_keywords  n  d  g  c  a  h  m  o
# ID
# 0                            normal fundus  0  0  0  1  0  0  0  0
# 1                            normal fundus  1  0  0  0  0  0  0  0
# 2   moderate non proliferative retinopathy  0  1  0  0  0  0  0  1
# 3          branch retinal artery occlusion  0  0  0  0  0  0  0  1
# 4        mild nonproliferative retinopathy  0  1  0  0  0  0  0  1

# %%
df['left-fundus'].value_counts(ascending=False)
# Out:
# 0_left.jpg       1
# 2960_left.jpg    1
# 2949_left.jpg    1
# 2950_left.jpg    1
# 2951_left.jpg    1
#                 ..
# 1243_left.jpg    1
# 1245_left.jpg    1
# 1246_left.jpg    1
# 1247_left.jpg    1
# 4784_left.jpg    1
# Name: left-fundus, Length: 3500, dtype: int64

# %% [markdown]
# # Normal Eye Sample

# %%
normal_full=df[df['n'] == 1]

# %% [markdown]
# ## Left Eye

# %%
#pull out only normal eyes
normal_left=normal_full[normal_full['left-diagnostic_keywords'].str.contains('normal fundus')]

# %%
normal_left.head()
# Out:
#      patient_age patient_sex   left-fundus   right-fundus  \
# ID
# 1             57        Male    1_left.jpg    1_right.jpg
# 8             59        Male    8_left.jpg    8_right.jpg
# 84            51      Female   84_left.jpg   84_right.jpg
# 191           51      Female  191_left.jpg  191_right.jpg
# 394           63        Male  394_left.jpg  394_right.jpg
#
#     left-diagnostic_keywords right-diagnostic_keywords  n  d  g  c  a  h  m  o
# ID
# 1              normal fundus             normal fundus  1  0  0  0  0  0  0  0
# 8              normal fundus             normal fundus  1  0  0  0  0  0  0  0
# 84             normal fundus             normal fundus  1  0  0  0  0  0  0  0
# 191            normal fundus             normal fundus  1  0  0  0  0  0  0  0
# 394            normal fundus             normal fundus  1  0  0  0  0  0  0  0

# %%
normal_left.shape
# Out:
# (1136, 14)

# %%
normal_left['left-fundus'].nunique()
# Out:
# 1136

# %%
#checked to see how many unique key diagnostic labels
nl=normal_left.groupby(['left-diagnostic_keywords']).sum()
nl
# Out:
#                              patient_age     n  d  g  c  a  h  m  o
# left-diagnostic_keywords
# lens dust，normal fundus             4790    86  0  0  0  0  0  0  0
# normal fundus                      58045  1023  0  0  0  0  0  0  0
# normal fundus，lens dust             1407    25  0  0  0  0  0  0  0
# normal fundus，normal fundus          101     2  0  0  0  0  0  0  0

# %%
#to remove any other conditions, pure sample
normal_left2=normal_left[~normal_left['left-diagnostic_keywords'].str.contains('dust')]

# %%
#check to ensure only patients with normal eyes were included in list
al_check=normal_left2.groupby(['left-diagnostic_keywords']).sum()
al_check
# Out:
#                              patient_age     n  d  g  c  a  h  m  o
# left-diagnostic_keywords
# normal fundus                      58045  1023  0  0  0  0  0  0  0
# normal fundus，normal fundus          101     2  0  0  0  0  0  0  0

# %% [markdown]
# ## Right Eye

# %%
#pull out only normal eyes
normal_right=normal_full[normal_full['right-diagnostic_keywords'].str.contains('normal fundus')]

# %%
#checked to see how many unique key diagnostic labels
nr=normal_right.groupby(['right-diagnostic_keywords']).sum()
nr
# Out:
#                            patient_age     n  d  g  c  a  h  m  o
# right-diagnostic_keywords
# lens dust，normal fundus           4835    88  0  0  0  0  0  0  0
# normal fundus                    58579  1033  0  0  0  0  0  0  0
# normal fundus，lens dust           1080    18  0  0  0  0  0  0  0

# %%
#to remove any other conditions, pure sample
normal_right2=normal_right[~normal_right['right-diagnostic_keywords'].str.contains('dust')]

# %%
#check to ensure only patients with normal eyes were included in list
ar_check=normal_right2.groupby(['right-diagnostic_keywords']).sum()
ar_check
# Out:
#                            patient_age     n  d  g  c  a  h  m  o
# right-diagnostic_keywords
# normal fundus                    58579  1033  0  0  0  0  0  0  0

# %%
#make a list of images for normal sample
normal_list_images=list(normal_left2['left-fundus'])+list(normal_right2['right-fundus'])
len(normal_list_images)
# Out:
# 2058

# %% [markdown]
# # Diabetic Eyes

# %%
diabetic_full=df[df['d'] == 1]
diabetic_full.shape
# Out:
# (1128, 14)

# %% [markdown]
# ## Left Eye

# %%
#pull out only diabetic eyes for left side
diabetic_left=diabetic_full[diabetic_full['left-diagnostic_keywords'].str.contains('diabetic retinopathy')]
diabetic_left.shape
# Out:
# (49, 14)

# %%
#checked to see how many unique key diagnostic labels
dl=diabetic_left.groupby(['left-diagnostic_keywords']).sum()
dl
# Out:
#                                                     patient_age  n   d  g  c  \
# left-diagnostic_keywords
# diabetic retinopathy                                        602  0  10  2  0
# diabetic retinopathy，dry age-related macular de...           52  0   1  0  0
# diabetic retinopathy，post laser photocoagulation            125  0   2  0  0
# diabetic retinopathy，wet age-related macular de...           59  0   1  0  0
# diabetic retinopathy，wet age-related macular de...           42  0   1  0  0
# dry age-related macular degeneration，diabetic r...          185  0   3  0  0
# epiretinal membrane，laser spot，severe prolifera...           38  0   1  0  0
# glaucoma，diabetic retinopathy                               359  0   6  6  0
# hypertensive retinopathy,diabetic retinopathy                55  0   1  0  0
# hypertensive retinopathy，diabetic retinopathy                56  0   1  0  0
# hypertensive retinopathy，suspected diabetic ret...           64  0   1  0  0
# laser spot，proliferative diabetic retinopathy，w...           56  0   1  0  0
# laser spot，severe proliferative diabetic retino...           55  0   1  0  1
# post laser photocoagulation，diabetic retinopathy             56  0   1  0  0
# post retinal laser surgery，diabetic retinopathy             116  0   2  0  0
# post retinal laser surgery，proliferative diabet...           62  0   1  0  0
# proliferative diabetic retinopathy                          291  0   5  0  0
# proliferative diabetic retinopathy，hypertensive...           95  0   2  0  0
# retinal pigment epithelium atrophy，diabetic ret...           54  0   1  0  0
# severe proliferative diabetic retinopathy                   342  0   6  0  2
# suspected glaucoma，suspicious diabetic retinopathy           59  0   1  1  0
#
#                                                     a  h  m  o
# left-diagnostic_keywords
# diabetic retinopathy                                4  0  0  2
# diabetic retinopathy，dry age-related macular de...  1  0  0  0
# diabetic retinopathy，post laser photocoagulation    0  0  0  2
# diabetic retinopathy，wet age-related macular de...  1  0  0  0
# diabetic retinopathy，wet age-related macular de...  1  0  0  1
# dry age-related macular degeneration，diabetic r...  3  0  0  0
# epiretinal membrane，laser spot，severe prolifera...  0  0  0  1
# glaucoma，diabetic retinopathy                       0  0  0  0
# hypertensive retinopathy,diabetic retinopathy       0  1  0  1
# hypertensive retinopathy，diabetic retinopathy       0  1  0  0
# hypertensive retinopathy，suspected diabetic ret...  0  1  0  0
# laser spot，proliferative diabetic retinopathy，w...  0  0  0  1
# laser spot，severe proliferative diabetic retino...  0  0  0  1
# post laser photocoagulation，diabetic retinopathy    0  0  0  1
# post retinal laser surgery，diabetic retinopathy     0  0  0  2
# post retinal laser surgery，proliferative diabet...  0  0  0  1
# proliferative diabetic retinopathy                  0  0  0  0
# proliferative diabetic retinopathy，hypertensive...  0  2  0  0
# retinal pigment epithelium atrophy，diabetic ret...  0  0  0  1
# severe proliferative diabetic retinopathy           0  0  0  2
# suspected glaucoma，suspicious diabetic retinopathy  0  0  0  0

# %%
#to remove any other conditions, pure sample
diabetic_left2=diabetic_left[~diabetic_left['left-diagnostic_keywords'].str.contains('atrophy|glaucoma|laser|dust|hypertensive|age-related')]

# %%
diabetic_other=diabetic_left2
diabetic_left2.shape
# Out:
# (21, 14)

# %%
#check to ensure only patients with diabetic eyes were included in list
dl_check=diabetic_left2.groupby(['left-diagnostic_keywords']).sum()
dl_check
# Out:
#                                            patient_age  n   d  g  c  a  h  m  \
# left-diagnostic_keywords
# diabetic retinopathy                               602  0  10  2  0  4  0  0
# proliferative diabetic retinopathy                 291  0   5  0  0  0  0  0
# severe proliferative diabetic retinopathy          342  0   6  0  2  0  0  0
#
#                                            o
# left-diagnostic_keywords
# diabetic retinopathy                       2
# proliferative diabetic retinopathy         0
# severe proliferative diabetic retinopathy  2

# %% [markdown]
# ## Right Eye

# %%
#pull out only diabetic eyes (right side)
diabetic_right=diabetic_full[diabetic_full['right-diagnostic_keywords'].str.contains('diabetic retinopathy')]

# %%
diabetic_right['right-fundus'].nunique()
# Out:
# 46

# %%
#checked to see how many unique key diagnostic labels
dr=diabetic_right.groupby(['right-diagnostic_keywords']).sum()
dr
# Out:
#                                                     patient_age  n  d  g  c  \
# right-diagnostic_keywords
# diabetic retinopathy                                        293  0  5  0  0
# diabetic retinopathy，dry age-related macular de...          200  0  3  0  0
# diabetic retinopathy，macular epiretinal membrane             42  0  1  0  0
# diabetic retinopathy，post laser photocoagulation             63  0  1  0  0
# dry age-related macular degeneration，diabetic r...          209  0  3  0  0
# glaucoma，diabetic retinopathy                               337  0  6  6  0
# hypertensive retinopathy，diabetic retinopathy                56  0  1  0  0
# hypertensive retinopathy，suspected diabetic ret...           64  0  1  0  0
# macular epiretinal membrane，diabetic retinopathy             80  0  1  0  0
# optic disk photographically invisible，diabetic ...           67  0  1  1  0
# post laser photocoagulation,diabetic retinopath...           56  0  1  0  0
# post retinal laser surgery，diabetic retinopathy             116  0  2  0  0
# post retinal laser surgery，proliferative diabet...           62  0  1  0  0
# post retinal laser surgery，proliferative diabet...           67  0  1  0  1
# proliferative diabetic retinopathy                          515  0  9  0  0
# proliferative diabetic retinopathy，hypertensive...          219  0  4  0  0
# severe proliferative diabetic retinopathy                    70  0  1  0  0
# severe proliferative diabetic retinopathy，laser...           49  0  1  0  0
# suspected glaucoma，suspicious diabetic retinopathy           59  0  1  1  0
# wet age-related macular degeneration，diabetic r...           56  0  1  0  0
# white vessel，proliferative diabetic retinopathy...           48  0  1  0  0
#
#                                                     a  h  m  o
# right-diagnostic_keywords
# diabetic retinopathy                                2  0  0  1
# diabetic retinopathy，dry age-related macular de...  3  0  1  0
# diabetic retinopathy，macular epiretinal membrane    1  0  0  1
# diabetic retinopathy，post laser photocoagulation    0  0  0  1
# dry age-related macular degeneration，diabetic r...  3  0  0  0
# glaucoma，diabetic retinopathy                       0  0  0  0
# hypertensive retinopathy，diabetic retinopathy       0  1  0  0
# hypertensive retinopathy，suspected diabetic ret...  0  1  0  0
# macular epiretinal membrane，diabetic retinopathy    0  0  0  1
# optic disk photographically invisible，diabetic ...  0  0  0  0
# post laser photocoagulation,diabetic retinopath...  0  0  0  1
# post retinal laser surgery，diabetic retinopathy     0  0  0  2
# post retinal laser surgery，proliferative diabet...  0  0  0  1
# post retinal laser surgery，proliferative diabet...  0  0  0  1
# proliferative diabetic retinopathy                  0  0  0  0
# proliferative diabetic retinopathy，hypertensive...  0  4  0  0
# severe proliferative diabetic retinopathy           0  0  0  0
# severe proliferative diabetic retinopathy，laser...  0  0  0  1
# suspected glaucoma，suspicious diabetic retinopathy  0  0  0  0
# wet age-related macular degeneration，diabetic r...  1  0  0  0
# white vessel，proliferative diabetic retinopathy...  0  0  0  1

# %%
#to remove any other conditions, pure sample
diabetic_right2=diabetic_right[~diabetic_right['right-diagnostic_keywords'].str.contains('atrophy|glaucoma|laser|dust|hypertensive|age-related|membrane|optic|white')]

# %%
diabetic_right2
# Out:
#       patient_age patient_sex    left-fundus    right-fundus  \
# ID
# 67             56        Male    67_left.jpg    67_right.jpg
# 234            54        Male   234_left.jpg   234_right.jpg
# 249            64        Male   249_left.jpg   249_right.jpg
# 412            60      Female   412_left.jpg   412_right.jpg
# 712            62        Male   712_left.jpg   712_right.jpg
# 978            59        Male   978_left.jpg   978_right.jpg
# 1838           62        Male  1838_left.jpg  1838_right.jpg
# 3994           70      Female  3994_left.jpg  3994_right.jpg
# 4002           67        Male  4002_left.jpg  4002_right.jpg
# 4073           52        Male  4073_left.jpg  4073_right.jpg
# 4131           56      Female  4131_left.jpg  4131_right.jpg
# 4391           47        Male  4391_left.jpg  4391_right.jpg
# 4624           60        Male  4624_left.jpg  4624_right.jpg
# 4631           46        Male  4631_left.jpg  4631_right.jpg
# 4686           63        Male  4686_left.jpg  4686_right.jpg
#
#                                left-diagnostic_keywords  \
# ID
# 67                                 diabetic retinopathy
# 234                                diabetic retinopathy
# 249              moderate non proliferative retinopathy
# 412                 severe nonproliferative retinopathy
# 712                wet age-related macular degeneration
# 978   diabetic retinopathy，wet age-related macular d...
# 1838   diabetic retinopathy，post laser photocoagulation
# 3994             moderate non proliferative retinopathy
# 4002                severe nonproliferative retinopathy
# 4073             moderate non proliferative retinopathy
# 4131                 proliferative diabetic retinopathy
# 4391             moderate non proliferative retinopathy
# 4624                 proliferative diabetic retinopathy
# 4631                severe nonproliferative retinopathy
# 4686                severe nonproliferative retinopathy
#
#                       right-diagnostic_keywords  n  d  g  c  a  h  m  o
# ID
# 67                         diabetic retinopathy  0  1  0  0  0  0  0  0
# 234                        diabetic retinopathy  0  1  0  0  0  0  0  0
# 249          proliferative diabetic retinopathy  0  1  0  0  0  0  0  0
# 412          proliferative diabetic retinopathy  0  1  0  0  0  0  0  0
# 712                        diabetic retinopathy  0  1  0  0  1  0  0  0
# 978                        diabetic retinopathy  0  1  0  0  1  0  0  0
# 1838                       diabetic retinopathy  0  1  0  0  0  0  0  1
# 3994  severe proliferative diabetic retinopathy  0  1  0  0  0  0  0  0
# 4002         proliferative diabetic retinopathy  0  1  0  0  0  0  0  0
# 4073         proliferative diabetic retinopathy  0  1  0  0  0  0  0  0
# 4131         proliferative diabetic retinopathy  0  1  0  0  0  0  0  0
# 4391         proliferative diabetic retinopathy  0  1  0  0  0  0  0  0
# 4624         proliferative diabetic retinopathy  0  1  0  0  0  0  0  0
# 4631         proliferative diabetic retinopathy  0  1  0  0  0  0  0  0
# 4686         proliferative diabetic retinopathy  0  1  0  0  0  0  0  0

# %%
#check to ensure only patients with diabetic eyes were included in list
dr_check=diabetic_right2.groupby(['right-diagnostic_keywords']).sum()
dr_check
# Out:
#                                            patient_age  n  d  g  c  a  h  m  o
# right-diagnostic_keywords
# diabetic retinopathy                               293  0  5  0  0  2  0  0  1
# proliferative diabetic retinopathy                 515  0  9  0  0  0  0  0  0
# severe proliferative diabetic retinopathy           70  0  1  0  0  0  0  0  0

# %%
dlist_left=list(diabetic_left2['left-fundus'])
#dlist_left

# %%
#make a list of images for diabetic sample
diabetic_list_images=list(diabetic_left2['left-fundus'])+list(diabetic_right2['right-fundus'])
len(diabetic_list_images)
# Out:
# 36

# %%
#diabetic_list_images

# %% [markdown]
# # EDA

# %% [markdown]
# Normal (N),\
# Diabetes (D),\
# Glaucoma (G),\
# Cataract (C),\
# Age related Macular Degeneration (A),\
# Hypertension (H),\
# Pathological Myopia (M),\
# Other diseases/abnormalities (O)

# %%
df.shape

# %%
df.info()

# %%
df.isna().count()

# %% [markdown]
# **Structure of numerical features**\
# \
# This process will give us some insights about the number of binary (2 unique values), \
# ordinal (3 to ~10 unique values) and continuous (more than 10 unique values) features in the dataset.

# %%
# For each numerical feature compute number of unique entries
unique_values = df.select_dtypes(include="number").nunique().sort_values()

# Plot information with y-axis in log-scale
unique_values.plot.bar(logy=True, figsize=(15, 4), title="Unique values per feature");

# %%
df.describe()

# %% [markdown]
# ## Heatmap-to see if any missing values

# %%
plt.figure(figsize=(10, 8))
plt.imshow(df.isna(), aspect="auto", interpolation="nearest", cmap="gray")
plt.xlabel("Column Number")
plt.ylabel("Sample Number");

# %%
# Plots the histogram for each numerical feature in a separate subplot
df.hist(bins=20, figsize=(15, 25), layout=(-1, 5), edgecolor="black")
plt.tight_layout();

# %%
df.columns

# %%
df.groupby(df['labels'])['patient_age'].count().plot.bar()

# %%
df.groupby(df['labels'])['patient_sex'].count().plot.bar()

# %%
sns.pairplot(
    df, plot_kws={"s": 50, "alpha": .4},hue = "patient_sex", palette="Set2",
    x_vars=["patient_age"],
    y_vars="labels",
    height = 7, aspect =1,
    );

# %%
# Computes feature correlation
df_corr = df.corr(method="pearson")

# %%
# Create labels for the correlation matrix
labels = np.where(np.abs(df_corr)>0.75, "S",
                  np.where(np.abs(df_corr)>0.5, "M",
                           np.where(np.abs(df_corr)>0.25, "W", "")))

# Plot correlation matrix
plt.figure(figsize=(15, 15))
sns.heatmap(df_corr, mask=np.eye(len(df_corr)), square=True,
            center=0, annot=labels, fmt='', linewidths=.5,
            cmap="vlag", cbar_kws={"shrink": 0.8});

# %% [markdown]
# ## Pull diabetic info

# %% [markdown]
# I am interested in diabetic retinopathy therefore I will pull the data for normal eye and those diagnosed with diabetes

# %% [markdown]
# # Images

# %% [markdown]
# ## Pull normal and diabetic images from pool of images

# %%
#move the normal images to normal folder and diabetic images to diabetic folder

src_dir = "/Users/karenbolon/Documents/spiced_projects/sandbox_dir/Project/images/"
dst_dir = "/Users/karenbolon/Documents/spiced_projects/sandbox_dir/Project/data/normal/"
dst_dir2 = "/Users/karenbolon/Documents/spiced_projects/sandbox_dir/Project/data/diabetic/"

# %%
for jpgfile in os.listdir(src_dir):
        if jpgfile in normal_list_images:
            shutil.copy(os.path.join(src_dir, jpgfile), dst_dir)

# %%
for jpgfile in os.listdir(src_dir):
        if jpgfile in diabetic_list_images:
            shutil.copy(os.path.join(src_dir, jpgfile), dst_dir2)

# %%
src_dir1 = "/Users/karenbolon/Documents/spiced_projects/sandbox_dir/Project/data/normal/"
src_dir2 = "/Users/karenbolon/Documents/spiced_projects/sandbox_dir/Project/data/diabetic/"
dst_dir3 = "/Users/karenbolon/Documents/spiced_projects/sandbox_dir/Project/test/normal/"
dst_dir4 = "/Users/karenbolon/Documents/spiced_projects/sandbox_dir/Project/test/diabetic/"

# %%
#to copy files over for test
normal_list = 1

for jpgfile in os.listdir(src_dir1):
    if normal_list <36 :
        shutil.copy(os.path.join(src_dir1, jpgfile), dst_dir3)
        normal_list += 1

# %%
#to copy files over for test
diabetic_list=1

for jpgfile in os.listdir(src_dir2):
    if diabetic_list <=36:
        shutil.copy(os.path.join(src_dir2, jpgfile), dst_dir4)        
        diabetic_list +=1

# %% [markdown]
# ## Import Images

# %%
classes = ['normal', 'diabetic']
base_path = 'test/'

# %%
# define an image data generator
data_gen = preprocessing.image.ImageDataGenerator(
    # define the preprocessing function that should be applied to all images
    preprocessing_function=mobilenet_v2.preprocess_input,
    rescale=1/255,
    # fill_mode='nearest',
    # rotation_range=20,
    # width_shift_range=0.2,
    # height_shift_range=0.2,
    # horizontal_flip=True, 
    # zoom_range=0.2,
    # shear_range=0.2    
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 # define an image data generator
# ----> 2 data_gen = preprocessing.image.ImageDataGenerator(
#       3     # define the preprocessing function that should be applied to all images
#       4     preprocessing_function=mobilenet_v2.preprocess_input,
#       5     rescale=1/255,
#       6     # fill_mode='nearest',
#       7     # rotation_range=20,
#       8     # width_shift_range=0.2,
#       9     # height_shift_range=0.2,
#      10     # horizontal_flip=True,
#      11     # zoom_range=0.2,
#      12     # shear_range=0.2
#      13 )
#
# NameError: name 'preprocessing' is not defined

# %%
# a generator that returns batches of X and y arrays
train_data_gen = data_gen.flow_from_directory(
        directory=base_path,
        class_mode="categorical",
        classes=classes,
        batch_size=71,  ## note: it's really images: 100 per category. this is mostly only working for models with transfer learning
        target_size=(224, 224)
)
# Out:
# Found 71 images belonging to 2 classes.

# %%
# load in all images at once
xtrain, ytrain = next(train_data_gen)
xtrain.shape, ytrain.shape
# Out:
# ((71, 224, 224, 3), (71, 2))

# %%
classes
# Out:
# ['normal', 'diabetic']

# %%
xtrain.dtype, ytrain.dtype
# Out:
# (dtype('float32'), dtype('float32'))

# %% [markdown]
# # Keras Sequential Model

# %% [markdown]
# tensorflow.keras.layers.Conv2D(filters, kernel_size, strides=(1, 1),
#   padding='valid', data_format=None, dilation_rate=(1, 1),
#   activation=None, use_bias=True, kernel_initializer='glorot_uniform',
#   bias_initializer='zeros', kernel_regularizer=None,
#   bias_regularizer=None, activity_regularizer=None,
#   kernel_constraint=None, bias_constraint=None)

# %%
# Clear session and build model:
K.clear_session()

model = Sequential([
    Conv2D(filters = 32, kernel_size = (3,3), strides = (1,1), padding = "valid", activation = "relu" ,input_shape = (224,224,3)),
    MaxPooling2D(pool_size = (2,2),strides=(2,2),padding = "valid"),

    Conv2D(filters = 64, kernel_size = (3,3), strides = (1,1), padding = "valid", activation = "relu"),
    MaxPooling2D(pool_size = (2,2),strides=(2,2),padding = "valid"),
    
    Conv2D(filters = 128, kernel_size = (3,3), strides = (1,1), padding = "valid", activation = "relu"),
    MaxPooling2D(pool_size = (2,2),strides=(2,2),padding = "valid"),
    
    Flatten(),
    
    #Fully connected layers:
    
    Dense(256, activation='relu'),
    Dropout(0.25),# - optional
    
    Dense(128, activation='relu'), BatchNormalization(),
    #Dropout(0.5),# - optional
    
    #Output layer:
    Dense(1 ,activation= "sigmoid") #"softmax")

    
])

# %%
# Check the summary:
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 128)               11075712
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 20)                2580
#
#  batch_normalization (BatchN  (None, 20)               80
#  ormalization)
#
#  dense_2 (Dense)             (None, 2)                 42
#
# =================================================================
# Total params: 11,171,662
# Trainable params: 11,171,622
# Non-trainable params: 40
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
# Early stopping:
early_stop = keras.callbacks.EarlyStopping(
    monitor='accuracy', #the thing we are monitoring
    min_delta=0.0005, #the minimum change in the quantity that we want for the model to train for another epoch
    patience=20, #number of epochs with no improvement needed for the model to stop
    verbose=1, #0 is silent, 1 means a message is displayed when something happens
    mode='auto'  
)

# %%
# Fit the model
history = model.fit(xtrain,ytrain,batch_size=50, epochs=300,validation_split=0.2)#, callbacks = [early_stop])
# Out:
# Epoch 1/300
# 2/2 [==============================] - 2s
300
# 2/2 [==============================] - 0s 120ms/step - loss: 0.5794 - accuracy: 0.7321 - val_loss: 0.7639 - val_accuracy: 0.6667
# Epoch 182/300
# 2/2 [==============================] - 0s 120ms/step - loss: 0.5617 - accuracy: 0.6964 - val_loss: 1.0374 - val_accuracy: 0.4667
# Epoch 183/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5185 - accuracy: 0.7500 - val_loss: 1.1467 - val_accuracy: 0.4667
# Epoch 184/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.6536 - accuracy: 0.6607 - val_loss: 0.8057 - val_accuracy: 0.7333
# Epoch 185/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5879 - accuracy: 0.6786 - val_loss: 1.1238 - val_accuracy: 0.6667
# Epoch 186/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.6249 - accuracy: 0.6786 - val_loss: 1.1043 - val_accuracy: 0.6667
# Epoch 187/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.6816 - accuracy: 0.5536 - val_loss: 1.0658 - val_accuracy: 0.6667
# Epoch 188/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.6632 - accuracy: 0.6071 - val_loss: 1.0769 - val_accuracy: 0.6667
# Epoch 189/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.7363 - accuracy: 0.4643 - val_loss: 1.2085 - val_accuracy: 0.6667
# Epoch 190/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.6974 - accuracy: 0.6250 - val_loss: 1.4496 - val_accuracy: 0.6667
# Epoch 191/300
# 2/2 [==============================] - 0s 111ms/step - loss: 0.6316 - accuracy: 0.7143 - val_loss: 1.3851 - val_accuracy: 0.6667
# Epoch 192/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.6065 - accuracy: 0.6607 - val_loss: 1.2376 - val_accuracy: 0.6000
# Epoch 193/300
# 2/2 [==============================] - 0s 141ms/step - loss: 0.4606 - accuracy: 0.8214 - val_loss: 1.5478 - val_accuracy: 0.4667
# Epoch 194/300
# 2/2 [==============================] - 0s 124ms/step - loss: 0.6198 - accuracy: 0.6786 - val_loss: 2.0902 - val_accuracy: 0.2667
# Epoch 195/300
# 2/2 [==============================] - 0s 120ms/step - loss: 0.5675 - accuracy: 0.7321 - val_loss: 2.1436 - val_accuracy: 0.2667
# Epoch 196/300
# 2/2 [==============================] - 0s 122ms/step - loss: 0.5896 - accuracy: 0.6786 - val_loss: 1.9828 - val_accuracy: 0.2667
# Epoch 197/300
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5509 - accuracy: 0.8214 - val_loss: 1.9842 - val_accuracy: 0.3333
# Epoch 198/300
# 2/2 [==============================] - 0s 113ms/step - loss: 0.5771 - accuracy: 0.7679 - val_loss: 1.6051 - val_accuracy: 0.3333
# Epoch 199/300
# 2/2 [==============================] - 0s 114ms/step - loss: 0.6252 - accuracy: 0.6607 - val_loss: 1.3131 - val_accuracy: 0.3333
# Epoch 200/300
# 2/2 [==============================] - 0s 120ms/step - loss: 0.6275 - accuracy: 0.6786 - val_loss: 1.1521 - val_accuracy: 0.3333
# Epoch 201/300
# 2/2 [==============================] - 0s 121ms/step - loss: 0.6082 - accuracy: 0.7500 - val_loss: 1.2776 - val_accuracy: 0.3333
# Epoch 202/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5794 - accuracy: 0.6786 - val_loss: 1.6101 - val_accuracy: 0.3333
# Epoch 203/300
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5736 - accuracy: 0.7679 - val_loss: 2.0810 - val_accuracy: 0.3333
# Epoch 204/300
# 2/2 [==============================] - 0s 120ms/step - loss: 0.5311 - accuracy: 0.7500 - val_loss: 2.0644 - val_accuracy: 0.2667
# Epoch 205/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5426 - accuracy: 0.7679 - val_loss: 1.4724 - val_accuracy: 0.3333
# Epoch 206/300
# 2/2 [==============================] - 0s 125ms/step - loss: 0.5736 - accuracy: 0.7500 - val_loss: 0.7759 - val_accuracy: 0.4667
# Epoch 207/300
# 2/2 [==============================] - 0s 122ms/step - loss: 0.5858 - accuracy: 0.7143 - val_loss: 0.6315 - val_accuracy: 0.6000
# Epoch 208/300
# 2/2 [==============================] - 0s 121ms/step - loss: 0.6136 - accuracy: 0.6786 - val_loss: 0.6373 - val_accuracy: 0.6667
# Epoch 209/300
# 2/2 [==============================] - 0s 120ms/step - loss: 0.6887 - accuracy: 0.5893 - val_loss: 0.6861 - val_accuracy: 0.5333
# Epoch 210/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5552 - accuracy: 0.7500 - val_loss: 1.0460 - val_accuracy: 0.4667
# Epoch 211/300
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5344 - accuracy: 0.7679 - val_loss: 1.9962 - val_accuracy: 0.2667
# Epoch 212/300
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5409 - accuracy: 0.7143 - val_loss: 3.0422 - val_accuracy: 0.2667
# Epoch 213/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.6118 - accuracy: 0.5714 - val_loss: 3.4272 - val_accuracy: 0.3333
# Epoch 214/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5910 - accuracy: 0.6607 - val_loss: 3.2832 - val_accuracy: 0.2667
# Epoch 215/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.6044 - accuracy: 0.6964 - val_loss: 1.2302 - val_accuracy: 0.3333
# Epoch 216/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5559 - accuracy: 0.7143 - val_loss: 0.6511 - val_accuracy: 0.7333
# Epoch 217/300
# 2/2 [==============================] - 0s 120ms/step - loss: 0.6368 - accuracy: 0.6429 - val_loss: 0.7749 - val_accuracy: 0.6667
# Epoch 218/300
# 2/2 [==============================] - 0s 121ms/step - loss: 0.6818 - accuracy: 0.6071 - val_loss: 0.7798 - val_accuracy: 0.6667
# Epoch 219/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.6163 - accuracy: 0.6607 - val_loss: 0.7373 - val_accuracy: 0.6667
# Epoch 220/300
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5385 - accuracy: 0.7321 - val_loss: 0.9661 - val_accuracy: 0.4667
# Epoch 221/300
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5864 - accuracy: 0.6429 - val_loss: 1.2209 - val_accuracy: 0.4000
# Epoch 222/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.6213 - accuracy: 0.6429 - val_loss: 1.4019 - val_accuracy: 0.2667
# Epoch 223/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5677 - accuracy: 0.7679 - val_loss: 1.3413 - val_accuracy: 0.4667
# Epoch 224/300
# 2/2 [==============================] - 0s 120ms/step - loss: 0.5508 - accuracy: 0.7500 - val_loss: 1.2007 - val_accuracy: 0.4667
# Epoch 225/300
# 2/2 [==============================] - 0s 120ms/step - loss: 0.4951 - accuracy: 0.7500 - val_loss: 1.2143 - val_accuracy: 0.5333
# Epoch 226/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5152 - accuracy: 0.7143 - val_loss: 1.2788 - val_accuracy: 0.4667
# Epoch 227/300
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5587 - accuracy: 0.7143 - val_loss: 1.2258 - val_accuracy: 0.4667
# Epoch 228/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5147 - accuracy: 0.7679 - val_loss: 1.2068 - val_accuracy: 0.4667
# Epoch 229/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5399 - accuracy: 0.7857 - val_loss: 1.2636 - val_accuracy: 0.4667
# Epoch 230/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.4997 - accuracy: 0.7679 - val_loss: 1.3125 - val_accuracy: 0.4667
# Epoch 231/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5389 - accuracy: 0.7500 - val_loss: 1.4145 - val_accuracy: 0.4000
# Epoch 232/300
# 2/2 [==============================] - 0s 114ms/step - loss: 0.4694 - accuracy: 0.8214 - val_loss: 1.5048 - val_accuracy: 0.2667
# Epoch 233/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5719 - accuracy: 0.7500 - val_loss: 1.5417 - val_accuracy: 0.2667
# Epoch 234/300
# 2/2 [==============================] - 0s 114ms/step - loss: 0.5555 - accuracy: 0.7321 - val_loss: 1.1285 - val_accuracy: 0.4667
# Epoch 235/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5724 - accuracy: 0.7143 - val_loss: 0.8721 - val_accuracy: 0.6667
# Epoch 236/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5564 - accuracy: 0.7321 - val_loss: 0.9174 - val_accuracy: 0.6667
# Epoch 237/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.6382 - accuracy: 0.6429 - val_loss: 0.9878 - val_accuracy: 0.6667
# Epoch 238/300
# 2/2 [==============================] - 0s 115ms/step - loss: 0.6896 - accuracy: 0.5536 - val_loss: 1.0091 - val_accuracy: 0.6667
# Epoch 239/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5785 - accuracy: 0.7321 - val_loss: 0.8789 - val_accuracy: 0.6667
# Epoch 240/300
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5775 - accuracy: 0.6964 - val_loss: 0.9440 - val_accuracy: 0.8000
# Epoch 241/300
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5571 - accuracy: 0.7679 - val_loss: 1.1157 - val_accuracy: 0.8000
# Epoch 242/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5926 - accuracy: 0.7500 - val_loss: 1.2735 - val_accuracy: 0.6000
# Epoch 243/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.4915 - accuracy: 0.7857 - val_loss: 1.5319 - val_accuracy: 0.4667
# Epoch 244/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5221 - accuracy: 0.7857 - val_loss: 1.7622 - val_accuracy: 0.2667
# Epoch 245/300
# 2/2 [==============================] - 0s 113ms/step - loss: 0.6707 - accuracy: 0.6429 - val_loss: 1.8198 - val_accuracy: 0.2000
# Epoch 246/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5489 - accuracy: 0.7143 - val_loss: 1.6350 - val_accuracy: 0.4667
# Epoch 247/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5238 - accuracy: 0.7143 - val_loss: 1.4635 - val_accuracy: 0.5333
# Epoch 248/300
# 2/2 [==============================] - 0s 113ms/step - loss: 0.5476 - accuracy: 0.7679 - val_loss: 1.5072 - val_accuracy: 0.6000
# Epoch 249/300
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5308 - accuracy: 0.7857 - val_loss: 1.5857 - val_accuracy: 0.4667
# Epoch 250/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5890 - accuracy: 0.7321 - val_loss: 1.4742 - val_accuracy: 0.6000
# Epoch 251/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5096 - accuracy: 0.7500 - val_loss: 1.3623 - val_accuracy: 0.8000
# Epoch 252/300
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5742 - accuracy: 0.7679 - val_loss: 1.1759 - val_accuracy: 0.6667
# Epoch 253/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.4926 - accuracy: 0.7500 - val_loss: 0.9306 - val_accuracy: 0.6667
# Epoch 254/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5870 - accuracy: 0.7143 - val_loss: 0.8031 - val_accuracy: 0.6667
# Epoch 255/300
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5947 - accuracy: 0.7321 - val_loss: 0.7161 - val_accuracy: 0.8000
# Epoch 256/300
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5669 - accuracy: 0.7500 - val_loss: 0.7183 - val_accuracy: 0.6667
# Epoch 257/300
# 2/2 [==============================] - 0s 113ms/step - loss: 0.4756 - accuracy: 0.8393 - val_loss: 0.7979 - val_accuracy: 0.5333
# Epoch 258/300
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5288 - accuracy: 0.7500 - val_loss: 0.8687 - val_accuracy: 0.4667
# Epoch 259/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5741 - accuracy: 0.6964 - val_loss: 0.9719 - val_accuracy: 0.4667
# Epoch 260/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5433 - accuracy: 0.7679 - val_loss: 1.2118 - val_accuracy: 0.4667
# Epoch 261/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5364 - accuracy: 0.7321 - val_loss: 1.4989 - val_accuracy: 0.2000
# Epoch 262/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5343 - accuracy: 0.7679 - val_loss: 1.6489 - val_accuracy: 0.2667
# Epoch 263/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5258 - accuracy: 0.8214 - val_loss: 1.7170 - val_accuracy: 0.2667
# Epoch 264/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5125 - accuracy: 0.7500 - val_loss: 1.7888 - val_accuracy: 0.2667
# Epoch 265/300
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5195 - accuracy: 0.7679 - val_loss: 1.9483 - val_accuracy: 0.2667
# Epoch 266/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5034 - accuracy: 0.7500 - val_loss: 1.8982 - val_accuracy: 0.2667
# Epoch 267/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5240 - accuracy: 0.7857 - val_loss: 1.7646 - val_accuracy: 0.2667
# Epoch 268/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5162 - accuracy: 0.7321 - val_loss: 1.7307 - val_accuracy: 0.2667
# Epoch 269/300
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5307 - accuracy: 0.7500 - val_loss: 1.8413 - val_accuracy: 0.2667
# Epoch 270/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5595 - accuracy: 0.7857 - val_loss: 2.1377 - val_accuracy: 0.2667
# Epoch 271/300
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5213 - accuracy: 0.7857 - val_loss: 2.3694 - val_accuracy: 0.3333
# Epoch 272/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.6194 - accuracy: 0.5714 - val_loss: 2.2340 - val_accuracy: 0.2667
# Epoch 273/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5490 - accuracy: 0.7500 - val_loss: 2.1333 - val_accuracy: 0.2667
# Epoch 274/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5447 - accuracy: 0.6964 - val_loss: 1.9099 - val_accuracy: 0.2667
# Epoch 275/300
# 2/2 [==============================] - 0s 115ms/step - loss: 0.4686 - accuracy: 0.8214 - val_loss: 1.4115 - val_accuracy: 0.4667
# Epoch 276/300
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5187 - accuracy: 0.7500 - val_loss: 1.1983 - val_accuracy: 0.6000
# Epoch 277/300
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5500 - accuracy: 0.7679 - val_loss: 1.1333 - val_accuracy: 0.8000
# Epoch 278/300
# 2/2 [==============================] - 0s 122ms/step - loss: 0.5330 - accuracy: 0.7321 - val_loss: 1.1004 - val_accuracy: 0.7333
# Epoch 279/300
# 2/2 [==============================] - 0s 122ms/step - loss: 0.5728 - accuracy: 0.7143 - val_loss: 1.0738 - val_accuracy: 0.6000
# Epoch 280/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.4931 - accuracy: 0.7679 - val_loss: 1.1798 - val_accuracy: 0.4667
# Epoch 281/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5575 - accuracy: 0.7321 - val_loss: 1.1827 - val_accuracy: 0.4667
# Epoch 282/300
# 2/2 [==============================] - 0s 119ms/step - loss: 0.4963 - accuracy: 0.7500 - val_loss: 1.1894 - val_accuracy: 0.4667
# Epoch 283/300
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5056 - accuracy: 0.7857 - val_loss: 1.1463 - val_accuracy: 0.4000
# Epoch 284/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5118 - accuracy: 0.7857 - val_loss: 1.1239 - val_accuracy: 0.6000
# Epoch 285/300
# 2/2 [==============================] - 0s 114ms/step - loss: 0.5127 - accuracy: 0.8036 - val_loss: 1.1495 - val_accuracy: 0.6000
# Epoch 286/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.4611 - accuracy: 0.8214 - val_loss: 1.4414 - val_accuracy: 0.4667
# Epoch 287/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.4826 - accuracy: 0.7679 - val_loss: 1.8770 - val_accuracy: 0.2667
# Epoch 288/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5027 - accuracy: 0.7321 - val_loss: 1.9835 - val_accuracy: 0.2667
# Epoch 289/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5873 - accuracy: 0.7143 - val_loss: 1.8833 - val_accuracy: 0.2667
# Epoch 290/300
# 2/2 [==============================] - 0s 122ms/step - loss: 0.5593 - accuracy: 0.7500 - val_loss: 1.5815 - val_accuracy: 0.2667
# Epoch 291/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5351 - accuracy: 0.7500 - val_loss: 1.2745 - val_accuracy: 0.4000
# Epoch 292/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.4932 - accuracy: 0.8036 - val_loss: 1.1716 - val_accuracy: 0.4667
# Epoch 293/300
# 2/2 [==============================] - 0s 113ms/step - loss: 0.5114 - accuracy: 0.7679 - val_loss: 1.1200 - val_accuracy: 0.6667
# Epoch 294/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5108 - accuracy: 0.7857 - val_loss: 1.2524 - val_accuracy: 0.6667
# Epoch 295/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5610 - accuracy: 0.6786 - val_loss: 1.6999 - val_accuracy: 0.6667
# Epoch 296/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.6204 - accuracy: 0.6964 - val_loss: 1.7162 - val_accuracy: 0.6667
# Epoch 297/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.6297 - accuracy: 0.5714 - val_loss: 1.5448 - val_accuracy: 0.6667
# Epoch 298/300
# 2/2 [==============================] - 0s 113ms/step - loss: 0.7096 - accuracy: 0.5000 - val_loss: 1.6113 - val_accuracy: 0.6667
# Epoch 299/300
# 2/2 [==============================] - 0s 119ms/step - loss: 0.7033 - accuracy: 0.5357 - val_loss: 1.6607 - val_accuracy: 0.6667
# Epoch 300/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5583 - accuracy: 0.7143 - val_loss: 1.5747 - val_accuracy: 0.6667

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(300)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# The training loss indicates how well the model is fitting the training data, while the validation loss indicates how well the model fits new data.
#
# Model is overfitting

# %% [markdown]
# # Image test

# %%
image=Image.open('data/normal/1_left.jpg')

# %%
width, height = image.size

# %%
print(width,height)
