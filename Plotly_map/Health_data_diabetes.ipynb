# %%
import pandas as pd

# %%
dfd=pd.read_csv('Diabetes_Time_Data.csv', index_col='Country Name')
dfd.head(2)
# Out:
#              Country Code                                        Series Name  \
# Country Name
# Afghanistan           AFG  Diabetes prevalence (% of population ages 20 t...
# Albania               ALB  Diabetes prevalence (% of population ages 20 t...
#
#                  Series Code 2009 [YR2009] 2010 [YR2010] 2011 [YR2011]  \
# Country Name
# Afghanistan   SH.STA.DIAB.ZS            ..            ..           7.6
# Albania       SH.STA.DIAB.ZS            ..            ..           2.8
#
#              2012 [YR2012] 2019 [YR2019] 2020 [YR2020] 2021 [YR2021]
# Country Name
# Afghanistan             ..            ..            ..          10.9
# Albania                 ..            ..            ..          10.2

# %%
dfd.shape
# Out:
# (271, 10)

# %%
df=pd.read_csv('Health_Data.csv')
df.head(2)
# Out:
#                                          Series Name     Series Code  \
# 0  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 1  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
#
#                   Country Name Country Code 1960 [YR1960] 1961 [YR1961]  \
# 0                  Afghanistan          AFG            ..            ..
# 1  Africa Eastern and Southern          AFE            ..            ..
#
#   1962 [YR1962] 1963 [YR1963] 1964 [YR1964] 1965 [YR1965]  ... 2012 [YR2012]  \
# 0            ..            ..            ..            ..  ...            ..
# 1            ..            ..            ..            ..  ...            ..
#
#   2013 [YR2013] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017]  \
# 0            ..            ..            ..            ..            ..
# 1            ..            ..            ..            ..            ..
#
#   2018 [YR2018] 2019 [YR2019] 2020 [YR2020]     2021 [YR2021]
# ...

# %%
df.head(2)
# Out:
#                                          Series Name     Series Code  \
# 0  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 1  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
#
#                   Country Name Country Code 1960 [YR1960] 1961 [YR1961]  \
# 0                  Afghanistan          AFG            ..            ..
# 1  Africa Eastern and Southern          AFE            ..            ..
#
#   1962 [YR1962] 1963 [YR1963] 1964 [YR1964] 1965 [YR1965]  ... 2012 [YR2012]  \
# 0            ..            ..            ..            ..  ...            ..
# 1            ..            ..            ..            ..  ...            ..
#
#   2013 [YR2013] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017]  \
# 0            ..            ..            ..            ..            ..
# 1            ..            ..            ..            ..            ..
#
#   2018 [YR2018] 2019 [YR2019] 2020 [YR2020]     2021 [YR2021]
# ...

# %%
# remove spaces in columns name
#df.columns = df.columns.str.replace(' ','_')

# %%
df.columns=df.columns.str.replace(']','')
# Out:
# /var/folders/xr/cfvb87194137h9lmpcxwzc5c0000gn/T/ipykernel_42720/2587377299.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns=df.columns.str.replace(']','')

# %%
df.columns=df.columns.str.replace('[','')
# Out:
# /var/folders/xr/cfvb87194137h9lmpcxwzc5c0000gn/T/ipykernel_42720/4156763662.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns=df.columns.str.replace('[','')

# %%
df.head(2)
# Out:
#                                          Series Name     Series Code  \
# 0  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 1  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
#
#                   Country Name Country Code 1960 YR1960 1961 YR1961  \
# 0                  Afghanistan          AFG          ..          ..
# 1  Africa Eastern and Southern          AFE          ..          ..
#
#   1962 YR1962 1963 YR1963 1964 YR1964 1965 YR1965  ... 2012 YR2012  \
# 0          ..          ..          ..          ..  ...          ..
# 1          ..          ..          ..          ..  ...          ..
#
#   2013 YR2013 2014 YR2014 2015 YR2015 2016 YR2016 2017 YR2017 2018 YR2018  \
# 0          ..          ..          ..          ..          ..          ..
# 1          ..          ..          ..          ..          ..          ..
#
#   2019 YR2019 2020 YR2020       2021 YR2021
# 0          ..          ..              10.9
# ...

# %%
df.isna().sum()
# Out:
# Series Name     3
# Series Code     5
# Country Name    5
# Country Code    5
# 1960 YR1960     5
#                ..
# 2017 YR2017     5
# 2018 YR2018     5
# 2019 YR2019     5
# 2020 YR2020     5
# 2021 YR2021     5
# Length: 66, dtype: int64

# %%
df.tail(5)
# Out:
#                                            Series Name Series Code  \
# 266                                                NaN         NaN
# 267                                                NaN         NaN
# 268                                                NaN         NaN
# 269  Data from database: Health Nutrition and Popul...         NaN
# 270                           Last Updated: 04/27/2022         NaN
#
#     Country Name Country Code 1960 YR1960 1961 YR1961 1962 YR1962 1963 YR1963  \
# 266          NaN          NaN         NaN         NaN         NaN         NaN
# 267          NaN          NaN         NaN         NaN         NaN         NaN
# 268          NaN          NaN         NaN         NaN         NaN         NaN
# 269          NaN          NaN         NaN         NaN         NaN         NaN
# 270          NaN          NaN         NaN         NaN         NaN         NaN
#
#     1964 YR1964 1965 YR1965  ... 2012 YR2012 2013 YR2013 2014 YR2014  \
# ...

# %%
df.drop(df.tail(5).index,
        inplace = True)

# %%
df.tail()
# Out:
#                                            Series Name     Series Code  \
# 261  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 262  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 263  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 264  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
# 265  Diabetes prevalence (% of population ages 20 t...  SH.STA.DIAB.ZS
#
#            Country Name Country Code 1960 YR1960 1961 YR1961 1962 YR1962  \
# 261  West Bank and Gaza          PSE          ..          ..          ..
# 262               World          WLD          ..          ..          ..
# 263         Yemen, Rep.          YEM          ..          ..          ..
# 264              Zambia          ZMB          ..          ..          ..
# 265            Zimbabwe          ZWE          ..          ..          ..
#
#     1963 YR1963 1964 YR1964 1965 YR1965  ... 2012 YR2012 2013 YR2013  \
# ...

# %%
df.isna().count()
# Out:
# Series Name     266
# Series Code     266
# Country Name    266
# Country Code    266
# 1960 YR1960     266
#                ...
# 2017 YR2017     266
# 2018 YR2018     266
# 2019 YR2019     266
# 2020 YR2020     266
# 2021 YR2021     266
# Length: 66, dtype: int64

# %%
df.shape
# Out:
# (266, 66)

# %%
df=df.replace('..', 0)

# %%
dfnew=df[['Country Name','Country Code', '2011 YR2011', '2021 YR2021']]

# %%
dfnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  266 non-null    object
#  1   Country Code  266 non-null    object
#  2   2011 YR2011   266 non-null    object
#  3   2021 YR2021   266 non-null    object
# dtypes: object(4)
# memory usage: 8.4+ KB

# %%
dfnew.describe()
# Out:
#        Country Name Country Code  2011 YR2011 2021 YR2021
# count           266          266          266         266
# unique          266          266          138         148
# top     Afghanistan          AFG            0         2.1
# freq              1            1           17          11

# %%
dfnew=dfnew.rename(columns = {'2011 YR2011': 2011,'2021 YR2021':2021})

# %%
dfnew.head(2)
# Out:
#                   Country Name Country Code              2011  \
# 0                  Afghanistan          AFG               7.6
# 1  Africa Eastern and Southern          AFE  4.59767537494877
#
#                2021
# 0              10.9
# 1  7.38817923540749

# %%
#dfnew.reset_index(level='Country Name')

# %%
dfn=dfnew[['Country Name', 'Country Code', 2011]]

# %%
dfb=dfnew[['Country Name', 'Country Code', 2021]]

# %%
dfn.head(2)
# Out:
#                   Country Name Country Code              2011
# 0                  Afghanistan          AFG               7.6
# 1  Africa Eastern and Southern          AFE  4.59767537494877

# %%
dfn['Year']=2011

# %%
dfn. rename(columns = {2011:'Diabetes_Rate'}, inplace = True)

# %%
dfn.head()
# Out:
#                   Country Name Country Code     Diabetes_Rate  Year
# 0                  Afghanistan          AFG               7.6  2011
# 1  Africa Eastern and Southern          AFE  4.59767537494877  2011
# 2   Africa Western and Central          AFW  4.42009859065853  2011
# 3                      Albania          ALB               2.8  2011
# 4                      Algeria          DZA                 7  2011

# %%
dfn.shape
# Out:
# (266, 4)

# %%
dfb.head(2)
# Out:
#                   Country Name Country Code              2021
# 0                  Afghanistan          AFG              10.9
# 1  Africa Eastern and Southern          AFE  7.38817923540749

# %%
dfb['Year']=2021

# %%
dfb. rename(columns = {2021:'Diabetes_Rate'}, inplace = True)

# %%
dfb.head()
# Out:
#                   Country Name Country Code     Diabetes_Rate  Year
# 0                  Afghanistan          AFG              10.9  2021
# 1  Africa Eastern and Southern          AFE  7.38817923540749  2021
# 2   Africa Western and Central          AFW  3.39726242955192  2021
# 3                      Albania          ALB              10.2  2021
# 4                      Algeria          DZA               7.1  2021

# %%
dfb.shape
# Out:
# (266, 4)

# %%
dflatest=pd.concat([dfn,dfb])

# %%
dflatest.shape
# Out:
# (532, 4)

# %%
dflatest.to_csv('dflatest.csv', index=False)
